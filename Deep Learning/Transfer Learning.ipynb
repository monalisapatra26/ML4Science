# %%
# !pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in c:\users\monal\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: protobuf>=3.8.0 in c:\users\monal\anaconda3\lib\site-packages (from tensorflow_hub) (3.19.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\monal\anaconda3\lib\site-packages (from tensorflow_hub) (1.21.5)

# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE = (224,224) 
 
classifier = tf.keras.Sequential([
    hub.KerasLayer("https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4",input_shape = IMAGE_SHAPE+(3,))])

# %%
Image.open('./images/ostrich.jpeg') #umbrella.png, violin.jpg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=260x194 at 0x180ABDDD160>

# %%
pic1=Image.open('./images/ostrich.jpeg').resize(IMAGE_SHAPE)
pic1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x1809CE78460>

# %%
pic1=np.array(pic1)/255.0
pic1.shape
# Out:
# (224, 224, 3)

# %%
pic1
# Out:
# array([[[0.83529412, 0.91764706, 0.92156863],
#         [0.83529412, 0.91764706, 0.92156863],
#         [0.83921569, 0.92156863, 0.9254902 ],
#         ...,
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078]],
#
#        [[0.83529412, 0.91764706, 0.92156863],
#         [0.83529412, 0.91764706, 0.92156863],
#         [0.83921569, 0.92156863, 0.9254902 ],
#         ...,
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078]],
#
#        [[0.83529412, 0.91764706, 0.92156863],
#         [0.83529412, 0.91764706, 0.92156863],
#         [0.83921569, 0.92156863, 0.9254902 ],
#         ...,
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078],
#         [0.8       , 0.88235294, 0.90196078]],
#
#        ...,
#
#        [[0.89019608, 0.80784314, 0.55294118],
#         [0.88235294, 0.8       , 0.54901961],
#         [0.88627451, 0.80392157, 0.55294118],
#         ...,
#         [0.90980392, 0.80392157, 0.52156863],
#         [0.89411765, 0.78823529, 0.50588235],
#         [0.8745098 , 0.76862745, 0.48627451]],
#
#        [[0.90980392, 0.82745098, 0.58431373],
#         [0.87843137, 0.79607843, 0.54901961],
#         [0.8745098 , 0.79215686, 0.54509804],
#         ...,
#         [0.90980392, 0.80784314, 0.51372549],
#         [0.89411765, 0.79215686, 0.50196078],
#         [0.8745098 , 0.77254902, 0.48235294]],
#
#        [[0.90980392, 0.82745098, 0.58039216],
#         [0.87843137, 0.79607843, 0.54901961],
#         [0.8745098 , 0.79215686, 0.54509804],
#         ...,
#         [0.90980392, 0.80784314, 0.51372549],
#         [0.89411765, 0.79215686, 0.50196078],
#         [0.8745098 , 0.77254902, 0.48235294]]])

# %%
pic1[np.newaxis,...].shape
# Out:
# (1, 224, 224, 3)

# %%
result=classifier.predict(pic1[np.newaxis,...])
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
result
# Out:
# array([[ 0.36717734, -0.9798395 , -1.4425666 , ..., -0.30898878,
#         -0.7250838 ,  0.57630587]], dtype=float32)

# %%
result.shape
# Out:
# (1, 1001)

# %%
predicted_label_index = np.argmax(result)
predicted_label_index
# Out:
# 10

# %%
with open('./ImageNetLabels.txt','r') as f:
    image_labels = f.read().splitlines()
image_labels[:11]
# Out:
# ['background',
#  'tench',
#  'goldfish',
#  'great white shark',
#  'tiger shark',
#  'hammerhead',
#  'electric ray',
#  'stingray',
#  'cock',
#  'hen',
#  'ostrich']

# %%
image_labels[predicted_label_index]
# Out:
# 'ostrich'

# %%
image_labels[795]
# Out:
# 'shower curtain'

# %%
image_labels[722]
# Out:
# 'pillow'
